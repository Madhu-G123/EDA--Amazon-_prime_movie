# %% [markdown]
# # **Project Name**    - Amazon Prime TV shows and movie

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
# ##### **Team Member 1 -** Madhu G Magundanavar

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# The Amazon Prime Movies dataset is a structured collection of information about films available on the Amazon Prime streaming platform. It provides rich metadata that helps analysts, researchers, and business professionals understand the composition of Prime’s movie catalog, audience preferences, and industry trends. The dataset typically includes attributes such as movie titles, release years, genres, directors, cast members, ratings, and availability details. By analyzing these features, one can uncover insights into content diversity, regional representation, and user engagement patterns. Key Features of the Dataset
#
# Movie Titles & Release Years
# Each entry contains the name of the movie along with its release year.
#
# This allows for temporal analysis, such as identifying trends in movie production over decades or examining how Prime balances classic films with modern releases.
#
# Genres
# Movies are categorized into genres like drama, comedy, action, thriller, romance, and documentary.
#
# Genre distribution analysis helps in understanding Prime’s content strategy and audience targeting.
#
# Directors & Cast
# The dataset often lists directors and leading actors.
#
# This enables exploration of collaborations, star power influence, and the presence of renowned filmmakers on the platform.
#
# Ratings & Scores
# Many datasets include IMDb ratings or viewer scores.
#
# These metrics provide a measure of quality and popularity, useful for identifying critically acclaimed versus commercially successful films.
#
# Country & Language Information
# Movies are tagged with their country of origin and primary language.
#
# This highlights Prime’s global reach and the diversity of its catalog, showing how much content is localized versus international.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The rapid growth of streaming platforms like Amazon Prime Video has created vast amounts of data related to movies, genres, ratings, release years, and audience preferences. While this data is valuable, it is often unstructured and difficult to analyze without proper computational tools. The challenge lies in applying Numerical Python programming techniques (using libraries such as NumPy, Pandas,seaborn, and Matplotlib) to process, analyze, and visualize this dataset in order to extract meaningful insights.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# The business objective of analyzing the Amazon Prime Video dataset using numerical Python programming is to leverage data-driven insights to enhance content strategy, improve user engagement, and strengthen competitive positioning in the streaming market.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
path="/content/drive/MyDrive/Copy of credits.csv.zip"
df=pd.read_csv(path)
df.head(5)

# %%
path="/content/drive/MyDrive/Colab Notebooks/Copy of titles.csv.zip"
df=pd.read_csv(path)
df.head(5)

# %%
import pandas as pd

credits_path = "/content/drive/MyDrive/Copy of credits.csv.zip"
titles_path = "/content/drive/MyDrive/Colab Notebooks/Copy of titles.csv.zip"

credits = pd.read_csv(credits_path)
titles = pd.read_csv(titles_path)

# %%
merged_df = titles.merge(credits, on="id", how="left")
merged_df.head(10)

# %% [markdown]
# ### Dataset Rows & Columns count

# %% [markdown]
# ### Dataset Information

# %%
# Dataset row and column count
print(f"Number of rows: {merged_df.shape[0]}")
print(f"Number of columns: {merged_df.shape[1]}")

# %%
# Dataset Info
merged_df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"Number of duplicate values: {merged_df.duplicated().sum()}")

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
print(f"Number of null values: {merged_df.isnull().count()}")

# %%
# Visualizing the missing values
print(f"Number of null values: {merged_df.isnull().sum()}")

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
#  - Dimensions: The merged_df DataFrame contains 125354 rows and 19 columns.
#  - Data Types and Non-Null Counts: I've already displayed the info() output, which shows the data type for each column and the count of non-null entries.
#  - Key observations include:
# Columns like id, title, type, release_year, runtime, genres, and production_countries are complete with no missing values.
# Columns with significant missing values include age_certification (around 68k missing), seasons (around 116k missing), imdb_id (around 5k missing), imdb_score (around 6k missing), imdb_votes (around 6k missing), tmdb_popularity (around 500 missing), tmdb_score (around 11k missing), person_id (around 1k missing), name (around 1k missing), character (around 17k missing), and role (around 1k missing).
#
#  - Duplicate Values: There are 168 duplicate rows in the dataset.Answer Here

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
print(f"Columns: {merged_df.columns.tolist()}")

# %%
# Dataset Describe
merged_df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# - **id**: (Object) Unique identifier for each title (movie or show).
# - **title**: (Object) The name of the movie or TV show.
# - **type**: (Object) Indicates whether the entry is a 'MOVIE' or 'SHOW'.
# - **description**: (Object) A brief summary or synopsis of the title.
# - **release_year**: (Integer) The year the title was released.
# - **age_certification**: (Object) The age rating or certification for the content (e.g., TV-PG, R, PG-13).
# - **runtime**: (Integer) The duration of the movie in minutes, or average episode runtime for shows.
# - **genres**: (Object) A list of genres associated with the title (e.g., 'comedy', 'drama').
# - **production_countries**: (Object) A list of countries where the title was produced.
# - **seasons**: (Float) The number of seasons available for TV shows. This will be null for movies.
# - **imdb_id**: (Object) The IMDb (Internet Movie Database) identifier for the title.
# - **imdb_score**: (Float) The user rating of the title on IMDb.
# - **imdb_votes**: (Float) The number of votes received for the IMDb score.
# - **tmdb_popularity**: (Float) The popularity score of the title on TMDB (The Movie Database).
# - **tmdb_score**: (Float) The user rating of the title on TMDB.
# - **person_id**: (Float) Unique identifier for the person (actor/director) associated with the credit.
# - **name**: (Object) The name of the person (actor/director).
# - **character**: (Object) The character played by the actor in the title. This will be null for directors.
# - **role**: (Object) The role of the person (e.g., 'ACTOR', 'DIRECTOR').

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
for column in merged_df.columns:
    print(f"Column '{column}': {merged_df[column].nunique()} unique values")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# %% [markdown]
# ### Handling Duplicate Values
#
# First, I will remove the 168 duplicate rows identified earlier to ensure that each observation in the dataset is unique. This is important for accurate analysis and to prevent skewed results, especially when performing aggregations or statistical calculations.

# %%
# Remove duplicate rows
merged_df.drop_duplicates(inplace=True)
print(f"Number of duplicate values after removal: {merged_df.duplicated().sum()}")

# %% [markdown]
# ### Handling Missing Values
#
# Next, I will address the missing values in the dataset. Based on the `info()` and `isnull().sum()` outputs, several columns have null entries. I will use appropriate strategies for different data types:
#
# *   **Numerical Columns:** For columns like `seasons`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, and `tmdb_score`, I'll impute missing values with the median. The median is robust to outliers and represents a typical value in the distribution.
# *   **Categorical/Object Columns:** For columns such as `description`, `age_certification`, `imdb_id`, `name`, `character`, and `role`, I'll fill missing values with a placeholder string like 'Unknown' or 'Missing'. This allows these rows to be retained for analysis without introducing NaN values into categorical operations.

# %%
# Impute missing numerical values with the median
for col in ['seasons', 'imdb_score', 'imdb_votes', 'tmdb_popularity', 'tmdb_score', 'person_id']:
    if col in merged_df.columns:
        merged_df[col].fillna(merged_df[col].median(), inplace=True)

# Impute missing categorical values with 'Unknown' or 'Missing'
merged_df['description'].fillna('No Description', inplace=True)
merged_df['age_certification'].fillna('Unknown', inplace=True)
merged_df['imdb_id'].fillna('Missing', inplace=True)
merged_df['name'].fillna('Unknown', inplace=True)
merged_df['character'].fillna('Unknown', inplace=True)
merged_df['role'].fillna('Unknown', inplace=True)

# Verify that missing values have been handled
print("Missing values after handling:")
print(merged_df.isnull().sum())

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ### Data Manipulations Performed:
#
# 1.  **Duplicate Removal:** I identified and removed 168 duplicate rows from the `merged_df` DataFrame. This ensures that each record is unique and prevents biases in subsequent analyses.
# 2.  **Missing Value Imputation for Numerical Columns:** For numerical columns such as `seasons`, `imdb_score`, `imdb_votes`, `tmdb_popularity`, `tmdb_score`, and `person_id`, missing values were imputed using the **median** of their respective columns. The median was chosen as it is less sensitive to outliers compared to the mean, providing a more robust central tendency for imputation.
# 3.  **Missing Value Imputation for Categorical/Object Columns:** For categorical and object type columns like `description`, `age_certification`, `imdb_id`, `name`, `character`, and `role`, missing values were filled with descriptive placeholder strings ('No Description', 'Unknown', or 'Missing'). This approach retains the rows for analysis while explicitly marking the absence of original data, rather than dropping potentially valuable rows.
#
# ### Insights Found:
#
# *   The dataset initially contained **168 duplicate entries**, which have now been successfully removed, leaving a clean dataset for analysis.
# *   A significant number of missing values, particularly in `seasons` (~116k), `age_certification` (~68k), `tmdb_score` (~11k), `imdb_id` (~5k), `imdb_score` (~6k), `imdb_votes` (~6k), and `character` (~17k), have been addressed. The dataset is now **completely free of missing values** across all columns.
#
# These manipulations have made the `merged_df` dataset analysis-ready, allowing for more accurate and reliable data visualization and statistical modeling without the complications of missing or redundant data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import shutil
import glob

# Copies all screenshots from temporary storage into Google Drive
for filepath in glob.glob('/content/Screenshot*.png'):
    shutil.copy(filepath, '/content/drive/MyDrive/')

print("All screenshots saved to Google Drive!")

# %% [markdown]
# # Chart 1: Pie chart

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 152956.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a pie chart for the 'Movies vs TV Shows' distribution because it is highly effective for visualizing the proportional representation of categories within a whole. In this case, it clearly illustrates the relative proportions of movies and TV shows in the Amazon Prime Video content library, making it easy to see which content type dominates the platform.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Overwhelming Majority of Movies:** The pie chart clearly illustrates that 'MOVIE' content constitutes a significantly larger proportion of the Amazon Prime Video content library in this dataset (8,511 entries) compared to 'SHOW' content (1,357 entries).
# *   **Dominance of Movies:** This visual representation reinforces that the platform's content catalog, based on this dataset, is heavily skewed towards movies.
# *   **Relatively Small Proportion of Shows:** TV shows represent a much smaller segment of the total content count, indicating a content mix that prioritizes feature films.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, understanding the distribution of movies versus TV shows can significantly help in creating a positive business impact for Amazon Prime Video:
#
# *   **Content Acquisition Strategy:** Knowing that movies heavily dominate the catalog can guide future content acquisition decisions. If the goal is to diversify or attract a new audience segment interested in TV shows, Amazon Prime Video might strategically invest more in acquiring or producing original TV series. Conversely, if the focus remains on movie dominance, this insight validates continued investment in films.
# *   **Marketing and Promotion:** This insight helps in tailoring marketing campaigns. If the majority of content is movies, marketing efforts can emphasize the vast movie library to attract new subscribers who prefer films. It can also highlight popular movie genres or new movie releases more prominently.
# *   **Audience Segmentation and Targeting:** The platform can analyze if the movie-heavy content caters to its primary audience or if there's a segment that is underserved by the current proportion of TV shows. This can lead to targeted campaigns to attract specific demographics.
# *   **Resource Allocation:** Understanding content distribution can inform where to allocate resources, from content licensing budgets to server space and recommendation algorithms. If movies are watched more, optimizing their delivery and discoverability is crucial.
# *   **Competitive Analysis:** This distribution can be compared against competitors (e.g., Netflix, HBO Max) to identify competitive advantages or areas where Amazon Prime Video might be lagging. If competitors have a stronger TV show library, this data points to a potential gap to fill.
#
# There are no insights that directly lead to negative growth in this specific chart, as it merely describes the current state of content distribution. However, a potential *missed opportunity* could arise if Amazon Prime Video's audience desires a more balanced mix of movies and TV shows, and the current movie-heavy catalog fails to meet that demand, potentially leading to subscriber churn or difficulty attracting new segments. This would not be negative growth per se, but rather a limitation in maximizing potential growth.

# %% [markdown]
# # Chart 2: line chart

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153135.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart was chosen to visualize the 'Titles released by year' because it is exceptionally good at displaying trends and changes over time. Each point on the line represents the number of distinct titles released in a given year, and the connecting lines clearly illustrate the progression and evolution of content releases over the entire period captured in the dataset. This makes it easy to identify growth, decline, or stability in content production over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Steady Growth until the 2000s:** From the early 1910s until the early 2000s, there was a relatively slow but steady increase in the number of titles released per year.
# *   **Accelerated Growth in the 21st Century:** Starting from the early 2000s, there's a noticeable acceleration in content production, with the number of titles released annually growing much more rapidly.
# *   **Peak in Recent Years:** The chart shows a significant surge in title releases, peaking around 2020-2021, indicating a period of intense content production or acquisition.
# *   **Recent Decline (2022 onwards):** There appears to be a sharp drop in the number of titles released in the most recent year (2022) compared to the peak. This could be due to various factors such as data cutoff, changes in production, or release strategies.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gained from the 'Titles released by year' line chart can significantly help in creating a positive business impact for Amazon Prime Video:
#
# *   **Strategic Content Planning:**
#     *   **Growth Trend Validation:** The chart confirms a substantial increase in content over time, especially from the early 2000s onwards. This validates past investments in content acquisition and production.
#     *   **Future Investment Strategy:** The peak around 2020-2021 followed by a decline in 2022 suggests a need to investigate the reasons for this recent downturn. If the decline is due to changes in production cycles or a data cut-off, it's important to understand this. If it's a genuine slowdown, Amazon Prime Video might need to re-evaluate its content investment strategy to maintain or accelerate growth, especially if competitors are increasing their content output.
#
# *   **Market Positioning and Competitiveness:**
#     *   **Aggressiveness in Content Acquisition:** The rapid acceleration of title releases in the 21st century highlights a period of aggressive expansion. This kind of data helps in benchmarking against competitors and understanding Amazon's market share in content volume.
#     *   **Responding to Market Changes:** If the decline in 2022 is a trend across the industry (e.g., due to global events impacting production), then Amazon Prime Video's strategy might align with broader market dynamics. If it's unique to Amazon, it could signal a competitive disadvantage.
#
# *   **Audience Engagement and Retention:**
#     *   **Fresh Content Supply:** A continuous supply of new titles is crucial for subscriber acquisition and retention. Monitoring this trend ensures that Amazon Prime Video is consistently refreshing its library to keep viewers engaged and attract new ones.
#     *   **Content Library Strength:** The long history of title releases, going back to the 1910s, showcases the depth and breadth of Amazon's content library, which can be a strong selling point for audiences interested in older or classic films.
#
# There are no direct insights that lead to negative growth from this chart alone, as it primarily shows content volume. However, a potential negative impact could arise if:
#
# *   **Decline is Due to Lack of Investment:** If the recent decline is not addressed, it could lead to a perception of stagnation or a less compelling content offering compared to rivals, potentially impacting subscriber growth and retention.
# *   **Quality vs. Quantity Imbalance:** If the increase in titles during the growth phase came at the expense of content quality, it could lead to user dissatisfaction, even with a high volume of releases.

# %% [markdown]
# # Chart 3: Histogram

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153156.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram was chosen for the 'IMDb Rating Distribution' because it is an excellent chart type for visualizing the distribution of a continuous numerical variable (IMDb scores in this case). It allows us to easily see:
#
# *   **Shape of the Distribution:** Whether the scores are normally distributed, skewed, bimodal, etc.
# *   **Central Tendency:** Where the majority of the scores lie.
# *   **Spread/Variability:** How spread out the scores are.
# *   **Outliers:** Any unusually high or low scores that fall outside the typical range.
#
# The bars group scores into bins, and the height of each bar represents the frequency (or count) of titles falling within that score range, providing a clear visual summary of the IMDb ratings.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Concentration Around Mid-Range Scores:** The histogram shows a clear peak in the distribution around an IMDb score of 6.0. This indicates that a large number of titles on Amazon Prime Video have average to slightly above-average IMDb ratings.
# *   **General Skew towards Higher Scores:** While there's a peak at 6.0, the distribution overall suggests a higher prevalence of titles with scores between 5.0 and 7.0. There are fewer titles with very low scores (below 4.0) and also fewer, but still present, titles with very high scores (above 8.0).
# *   **Decreasing Frequency at Extremes:** The frequency of titles decreases as IMDb scores move towards the extreme ends (very low or very high), which is typical for rating distributions. Very few titles receive extremely low (e.g., 1.0-2.0) or extremely high (e.g., 9.0-9.5) scores.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gained from the 'IMDb Rating Distribution' histogram can help create a positive business impact for Amazon Prime Video:
#
# *   **Content Curation and Acquisition:**
#     *   **Identify Content Gaps:** If the platform aims to cater to a more discerning audience, the insights can highlight the need to acquire or produce content with higher IMDb scores (e.g., above 8.0), as these are currently less frequent. Conversely, if the strategy is to provide a broad range, the current distribution is well-aligned.
#     *   **Validate Acquisition Strategy:** The concentration around mid-range scores (5.0-7.0) suggests that Amazon Prime Video has a substantial library of generally well-received content. This validates content acquisition strategies that focus on broad appeal rather than exclusively niche, highly-rated content.
#
# *   **Marketing and Promotion:**
#     *   **Highlight Quality Content:** For titles with very high IMDb scores, marketing efforts can specifically leverage these ratings to attract users who prioritize critically acclaimed content. The platform can create curated lists or 'critically acclaimed' sections to promote these titles.
#     *   **Manage Expectations:** Understanding the typical score range helps manage user expectations. While promoting top-tier content, the platform can also market its mid-range content effectively, focusing on other attributes like genre, cast, or uniqueness.
#
# *   **Recommendation Algorithms:**
#     *   **Refine Recommendations:** The distribution insights can be fed into recommendation engines to improve personalization. If a user consistently watches movies in the 6.0-7.0 range, the algorithm can be tuned to recommend similar content more effectively.
#     *   **Discoverability:** Algorithms can be designed to increase the discoverability of high-scoring but perhaps less popular content, ensuring that hidden gems get exposure.
#
# There are no insights that directly lead to negative growth, as the chart primarily describes the existing quality landscape. However, a potential *missed opportunity* or risk could arise if:
#
# *   **Audience Demand for High-Rated Content is Unmet:** If a significant portion of Amazon Prime Video's target audience strongly prefers movies with very high IMDb scores, the current distribution, with its lower frequency of such titles, might lead to dissatisfaction or migration to competing platforms with a stronger catalog of highly-rated films.
# *   **Perception of Quality:** If the average IMDb score is perceived as 'just okay' by subscribers, it might not differentiate Amazon Prime Video strongly enough from competitors, potentially affecting new subscriber acquisition or retention if quality is a primary driver for their choice.

# %% [markdown]
# # Chart 4: Horizontal Bar Chart

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153215.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen for the 'Top 10 Genres' because it is ideal for comparing the magnitudes of different categories, especially when the category labels are long. In this case, 'genres' are discrete categories, and a horizontal layout allows for easy readability of each genre name without overlap, while the length of the bars clearly indicates the count of titles for each genre. This makes it straightforward to identify the most prevalent genres at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# *   **Dominance of Drama:** 'drama' is by far the most prevalent genre, indicating a significant portion of Amazon Prime Video's content falls into this category.
# *   **Strong Presence of Comedy:** 'comedy' is the second most popular genre, showing that humor-centric content also holds a substantial share.
# *   **Notable Documentation Content:** 'documentation' appears as the third most frequent genre, suggesting a healthy offering of factual and educational content.
# *   **Genre Hierarchy:** There's a clear hierarchy in content distribution, with 'drama' and 'comedy' significantly outnumbering other genres like 'thriller' and 'horror'.
# *   **Focus on Traditional Genres:** The top genres (drama, comedy, documentation, thriller, horror) represent widely popular and traditional categories, indicating a broad appeal content strategy.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gleaned from the 'Top 10 Genres' chart are crucial for Amazon Prime Video's strategic decisions and can lead to significant business impact, both positive and potentially negative:
#
# - Positive Business Impact:
#
# - Targeted Content Acquisition and Production:
# - Reinforce Strengths: The dominance of 'drama' and 'comedy' indicates these genres are popular and likely drive viewership. Amazon Prime Video can continue investing heavily in acquiring and producing high-quality content within these proven genres to satisfy existing subscribers and attract new ones.
# - Leverage Niche Popularity: The strong presence of 'documentation' suggests a dedicated audience for non-fiction content. Investing further in documentaries can cater to this segment and differentiate Amazon Prime Video from competitors.
# - Optimize Budget Allocation: Understanding which genres perform best helps allocate content budgets more effectively, prioritizing genres that yield the highest return on investment in terms of viewership and subscriber engagement.
# - Effective Marketing and Promotion:
# - Tailored Campaigns: Marketing efforts can be specifically designed to highlight the breadth and depth of content in the top genres, attracting viewers who prioritize these types of stories. For instance, promoting 'drama' or 'comedy' collections.
# - Audience Targeting: Knowing the most popular genres allows for better audience segmentation. Marketing teams can target potential subscribers who have shown interest in these genres on other platforms or through demographic data.
# - Enhanced User Experience and Discoverability:
# Curated Collections: The platform can create curated lists or dedicated sections for popular genres like 'drama' and 'comedy', making it easier for users to find content they love.
# - Recommendation Engine Refinement: These insights can inform and refine recommendation algorithms, ensuring that users are shown more content within their preferred genres, leading to higher engagement and retention.
# - Potential Negative Growth Insights / Missed Opportunities:
#
# - Lack of Content Diversification: While focusing on popular genres is good, an over-reliance on a few dominant genres (like drama and comedy) could lead to content fatigue for some viewers. If Amazon Prime Video doesn't sufficiently diversify its catalog to include a wider array of less dominant but growing genres, it risks alienating niche audiences or those looking for more varied  content experiences. This could lead to:
# - Subscriber Churn: Users might leave for platforms that offer a more balanced or diverse genre mix.
# Limited New Audience Acquisition: Potential subscribers whose primary interests lie outside the top genres might not find the platform appealing.
# - Ignoring Emerging Trends: If Amazon Prime Video becomes too fixated on historically popular genres, it might miss out on emerging genre trends or shifts in audience preferences. Failing to invest in new and popular genres could lead to a perceived outdated library.
# - Competitive Disadvantage: Competitors might strategically target underserved genre markets. If Amazon Prime Video neglects these areas, it could lose a competitive edge and allow rivals to capture significant market share in those segments.
# - Stagnation in Content Innovation: A heavy focus on a few established genres might stifle innovation in content creation, leading to a homogenous library and a lack of fresh, unique offerings that could excite and retain subscribers.

# %% [markdown]
# # Chart 5: Bar Chart 2

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153235.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was selected for the 'Top 10 Production Countries' for similar reasons as the 'Top 10 Genres' chart. It's highly effective for:
#
# - Comparing Magnitudes: It clearly shows the relative number of distinct titles produced by each country.
# - Readability of Labels: Production country names can sometimes be long. The horizontal orientation ensures that each country label is fully visible and easily readable without overlap, which would be a challenge with vertical bars.
# - Clear Ranking: The length of each bar directly corresponds to the count, making it straightforward to identify the dominant production countries at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# From the 'Top 10 Production Countries' chart, the following insights can be derived:
#
# - Dominance of the United States: The chart clearly shows that the United States (['US']) is the overwhelming leader in content production, with a significantly higher number of distinct titles compared to any other country.
# - India as a Strong Second: India (['IN']) holds the second position, indicating a substantial amount of content originating from the country, though it's considerably less than the US.
# - Presence of Unspecified Production Countries: A notable portion of content is attributed to [] (an empty list), which likely represents titles with unspecified or unknown production countries. This is a significant category and warrants further investigation.
# - United Kingdom and Canada are Key Contributors: The United Kingdom (['GB']) and Canada (['CA']) are also significant contributors, ranking third and fourth (excluding the unspecified category), respectively.
# - Diverse Global Representation: Beyond the top few, countries like Japan (['JP']), Australia (['AU']), China (['CN']), and France (['FR']) also feature in the top 10, highlighting a diverse global sourcing of content, albeit in smaller volumes.
# - Concentrated Production: While there is global representation, content production is highly concentrated in a few dominant countries, particularly the US.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, understanding the distribution of content by production country offers significant opportunities for Amazon Prime Video to drive positive business impact, while also highlighting areas that, if neglected, could lead to negative growth or missed strategic advantages:
#
# - Positive Business Impact:
#
# - Strategic Content Sourcing & Investment:
#  - Leverage Dominant Markets: The strong dominance of the US and India indicates robust content pipelines from these regions. Amazon Prime Video can continue to invest strategically in acquiring and producing content from these proven markets to satisfy existing audiences and capitalize on their high output. This could involve strengthening partnerships with production houses in these countries.
#  - Cultivate Emerging Markets: The presence of other countries like Japan, Australia, China, and France suggests a global content strategy. Amazon Prime Video can deepen its investment in these regions to cater to local preferences and expand its global subscriber base, potentially commissioning local original content that resonates culturally.
#  - Localized Content Strategy:
# Tailored Marketing: Marketing campaigns can be localized to highlight content from specific regions to target audiences in those countries or diasporas, enhancing relevance and appeal.
# Regional Expansion: Insights into strong production countries can guide decisions for market expansion, focusing on regions with high content production rates and potentially strong local viewership.
#  - Competitive Differentiation:
# Showcasing Diversity: Beyond the top producers, highlighting the diverse range of countries contributing content can serve as a unique selling proposition, attracting viewers looking for international and culturally varied programming.
#  - Identifying Gaps: By understanding what content is produced where, Amazon Prime Video can identify gaps in its offerings from certain regions and proactively seek content to fill those voids, staying ahead of competitors.
#  - Addressing Unspecified Content: Investigating the content with [] as its production country (the third largest category) can help in data completeness. Assigning proper country labels could reveal new, significant production hubs or enhance the accuracy of regional content analysis.
# -  Potential Negative Growth Insights / Missed Opportunities:
#
# - Over-reliance on Dominant Countries: While the US and India are major content producers, an excessive focus might lead to:
#  - Content Homogenization: A lack of diverse narratives and cultural perspectives if content primarily comes from only a few regions, potentially alienating audiences seeking different types of stories.
#  - Vulnerability to Market Shifts: If political, economic, or regulatory changes impact content production in a dominant country, Amazon Prime Video could face significant disruption to its content supply.
#  - Neglecting Underserved Markets: If Amazon Prime Video does not actively seek content from a wider array of countries, it risks:
# - Missing Out on Global Growth: Overlooking burgeoning production markets that could offer unique and high-quality content, thus losing potential new subscribers from those regions.
# Falling Behind Competitors: Rivals might strategically invest in these underserved markets, gaining a competitive advantage by offering content that Amazon Prime Video lacks.
#  - Lack of Transparency in Data ([] category): The large number of titles with unspecified production countries ([]) represents a missed opportunity for granular analysis and strategic decision-making. This lack of information could hinder:
#  - Accurate Regional Strategy: Inability to precisely target marketing or content acquisition efforts to actual content origins.
# - Misleading Insights: Other analyses based on production country might be skewed due to this significant 'unknown' category.
# - Failure to Diversify Production: If the distribution remains heavily skewed without a conscious effort to broaden the base, Amazon Prime Video might be perceived as less global or less inclusive in its content offerings, potentially affecting its brand image and appeal to a diverse international audience.

# %% [markdown]
# # Chart 6: Scatter Plot

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153300.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A scatter plot was chosen to visualize 'IMDb Score vs TMDB Score' because it is exceptionally effective for displaying the relationship between two continuous numerical variables. Specifically, it helps to:
#
#  - Identify Correlation: It allows us to visually assess if there's a positive, negative, or no correlation between IMDb scores and TMDB scores.
#  - Spot Trends and Patterns: We can observe if scores from both platforms generally agree, if one consistently rates higher than the other, or if there are specific clusters of data points.
#  - Detect Outliers: Individual data points that deviate significantly from the general trend can be easily identified, which might indicate content that is rated very differently across the two platforms.
#
# Each point on the scatter plot represents a title, with its x-coordinate being the IMDb score and its y-coordinate being the TMDB score. This direct mapping makes it easy to understand how the scores from these two rating systems compare for the same content.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?:

# %% [markdown]
# From the 'IMDb Score vs TMDB Score' scatter plot, the following insights can be observed:
#
#  - Positive Correlation: There is a generally strong positive correlation between IMDb scores and TMDB scores for both movies and shows. This indicates that content rated highly on IMDb tends to also be rated highly on TMDB, and vice-versa. Most data points cluster along a diagonal trend, suggesting that the two platforms generally agree on the quality of content.
# - Consistency in Ratings: While not perfectly identical, the scores from both platforms generally align, implying a consistent perception of content quality across different rating communities.
# - Predominance of Movies: The majority of the data points, particularly those with a wider range of scores, are represented by 'MOVIE' (orange circles), indicating a larger volume of movie titles in the dataset being compared.
# - Outlier/Distinction for Shows: There is one distinct blue data point representing 'SHOW' which appears to have a higher average IMDb score (around 7.0) compared to its TMDB score (around 3.0-3.5). This could indicate a specific show where one platform's audience rated it significantly higher or lower than the other, or it could be an anomaly. (Note: Only one show is visible in this particular chart snapshot, making it difficult to draw general conclusions for all shows).
#  - Concentration of Scores: Most scores for both platforms fall within the range of approximately 4.0 to 8.0, with fewer titles reaching the extreme ends of the scoring spectrum.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Yes, the insights gained from comparing IMDb and TMDB scores can significantly contribute to a positive business impact for Amazon Prime Video, while also revealing areas that could lead to negative growth or missed opportunities:
#
# Positive Business Impact:
#
# - Content Acquisition and Curation:
#  - Validated Quality: The strong positive correlation between IMDb and TMDB scores indicates that, for the most part, content quality is consistently perceived across different major platforms. This can validate existing content acquisition strategies for broadly appealing, high-quality titles.
#  - Efficiency in Vetting: When considering new content, Amazon Prime Video can leverage both IMDb and TMDB scores as reliable indicators of audience reception, streamlining the vetting process. Content with high scores on both platforms is likely a safe bet for audience satisfaction.
#  - Targeted Marketing and Recommendation Engine Improvement:
# Cross-Platform Appeal: For content that scores consistently high on both platforms, marketing can emphasize its universal appeal and critical acclaim, attracting a wider audience.
#  - Refined Recommendations: Understanding the correlation helps in refining recommendation algorithms. If a user enjoys content with a specific IMDb score, the system can confidently recommend titles with similar TMDB scores, increasing the likelihood of successful recommendations.
#  - Identifying Niche Audiences and Undervalued Content:
#  - Outlier Analysis: Investigating titles where IMDb and TMDB scores diverge significantly (the potential 'outliers') can be very valuable. For example, a show with a high IMDb score but a low TMDB score (like the one observed) might appeal strongly to a specific, perhaps more critical, audience segment. This could indicate a niche that Amazon Prime Video could further explore or market to specifically.
#  - Content Re-evaluation: Such discrepancies might also point to content that is undervalued by one platform's audience but highly appreciated by another's. Amazon Prime Video could highlight these titles to the appropriate audience segments, increasing engagement.
# - Potential Negative Growth Insights / Missed Opportunities:
#
#  - Neglecting Divergent Content: If Amazon Prime Video solely focuses on content with consistently high scores across both platforms, it might miss out on valuable niche content that resonates deeply with a smaller, but loyal, segment of its audience (like the 'SHOW' outlier). Ignoring such content could lead to:
#  - Alienating Niche Audiences: Audiences with specific tastes, whose preferred content might not achieve high scores across all platforms but is highly valued by them, could feel underserved and seek other platforms.
#  - Lack of Content Diversity: An over-emphasis on consensus-rated content might lead to a homogenous library, failing to capture diverse tastes and reducing the platform's unique selling propositions.
# - Underestimating Platform-Specific Bias: While there's a general correlation, small but consistent differences in how IMDb users vs. TMDB users rate content could indicate subtle audience biases or preferences on each platform. Failing to understand these nuances could lead to:
#  - Suboptimal Content Acquisition: Acquiring content that aligns well with one platform's audience but less so with the other could lead to underperformance on Amazon Prime Video if its user base leans towards the latter.
#  - Ineffective Marketing: Marketing strategies that don't account for these subtle biases might fail to connect with the target audience effectively.
#  - Data Quality Issues: If the discrepancies or outliers are due to data quality issues (e.g., incorrect merging, missing values influencing averages), relying on these insights without addressing the underlying data problems could lead to flawed business decisions and wasted resources.

# %% [markdown]
# # Chart 7: Tree Map

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153341.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A treemap was chosen to visualize 'Titles by Age Certification' because it is particularly effective for displaying hierarchical data and illustrating proportions within a whole. In this chart, it allows us to:
#
#  - Represent Hierarchy: We can easily see the breakdown of content by 'type' (Movie/Show) and then further by 'age certification' within each type, showing a nested structure.
# - Show Proportions: The size of each rectangular area directly corresponds to the number of titles within that category, making it simple to identify which age certifications and content types have the largest share.
# - Efficiently Use Space: Treemaps are space-efficient, allowing for a large amount of hierarchical data to be displayed in a compact visual format, which is ideal for comparing many categories simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?:

# %% [markdown]
# From the 'Titles by Age Certification' treemap, we can derive the following insights:
#
# - Dominance of Mature Movie Content: 'MOVIE R' (R-rated movies) represents the largest single category, indicating a significant portion of the Amazon Prime Video library is geared towards mature audiences. 'MOVIE PG-13' and 'MOVIE PG' also hold substantial shares, further emphasizing a strong presence of content for teen and general audiences.
# - Lower Volume of All-Ages Movies: 'MOVIE G' (General audience movies) is considerably smaller than the other movie age certifications, suggesting fewer titles specifically aimed at very young children or general family viewing that receive a 'G' rating.
# - Significant Volume of Mature TV Shows: For TV shows, 'SHOW TV-MA' (Mature Audience) and 'SHOW TV-14' (Ages 14 and up) are the largest categories, mirroring the trend of mature content dominance seen in movies.
# - Variety in TV Show Certifications: While mature TV shows are prominent, there's also a good distribution across 'SHOW TV-PG' (Parental Guidance Suggested), 'SHOW TV-Y' (All Children), 'SHOW TV-G' (General Audience), and 'SHOW TV-Y7' (Directed to Older Children), indicating a broader range of content for different age groups within the TV show category.
# - Movies Outweigh Shows in Certifications: Overall, movie categories (R, PG-13, PG, G) collectively occupy a much larger area of the treemap compared to TV show categories (TV-MA, TV-14, TV-PG, TV-Y, TV-G, TV-Y7), reinforcing the earlier insight about movie dominance in the content library.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Understanding the distribution of titles by age certification can lead to significant business impacts for Amazon Prime Video, both positive and potentially negative:
#
# Positive Business Impact:
#
# - Targeted Content Strategy:
#
#  - Reinforce Strengths: The dominance of 'MOVIE R' and 'SHOW TV-MA/TV-14' content suggests a strong appeal to adult and mature audiences. Amazon Prime Video can continue to invest in high-quality content within these categories, which likely drives a substantial portion of its viewership and subscriptions.
#  - Identify Growth Opportunities: The insights about the variety in TV show certifications (including content for children) indicate a potential to cater to family audiences. Strategic investment in more 'MOVIE G', 'MOVIE PG', 'SHOW TV-Y', or 'SHOW TV-G' content could attract new family-oriented subscribers and expand the platform's demographic reach.
# - Marketing and Audience Segmentation:
#
#  - Tailored Campaigns: Marketing can be specifically designed to highlight content relevant to different age groups. For instance, promoting the vast library of mature movies to adult audiences, while also showcasing family-friendly options to parents.
#  -Parental Controls Promotion: The diverse range of age-certified content allows Amazon Prime Video to promote its robust parental control features, assuring parents that their children can safely browse age-appropriate content.
# - Competitive Differentiation:
#
#  - Niche Market Capture: By strategically expanding its offerings in underserved age certification categories (e.g., more 'G' rated movies), Amazon Prime Video could carve out a niche and differentiate itself from competitors that may focus predominantly on mature content.
# - Potential Negative Growth Insights / Missed Opportunities:
#
#  - Alienating Specific Demographics:
#
#  - Underserved Family Audience: The relatively lower volume of all-ages movies ('MOVIE G') could mean that family audiences or households with young children might find the content library less appealing, potentially leading to lower subscription rates or higher churn in this segment if their needs are not met.
# - Content Homogeneity Risk: An over-reliance on mature content, particularly 'MOVIE R' and 'SHOW TV-MA', while successful with adult audiences, might lead to a perception of a less diverse library. This could deter viewers seeking a broader range of content for different moods or family viewing.
# - Competitive Disadvantage:
#
#  - Lost Market Share: If competitors actively invest in and successfully capture the family entertainment market (e.g., through more children-friendly movies and shows), Amazon Prime Video could lose a significant segment of potential subscribers.
#  - Brand Perception:
#
# Image as 'Adult-Focused' Platform: While not inherently negative, a strong skew towards mature content might inadvertently shape the platform's brand image as primarily an 'adult-focused' service. This could make it harder to attract or retain audiences looking for a more balanced or family-friendly streaming experience, potentially limiting overall market penetration.

# %% [markdown]
# # Chart 8: Horizontal Bar Chart

# %%
from IPython.display import Image, display

display(Image(filename='/content/drive/MyDrive/Screenshot 2026-09-08 153320.png', width=700))

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A horizontal bar chart was chosen for displaying the 'TOP 10 Actors' for several key reasons:
#
# - Clear Comparison of Magnitudes: It effectively shows the relative frequency or count for each actor, making it easy to see who has the most distinct appearances (ids) and rank them.
# - Readability of Labels: Actor names can vary in length. A horizontal orientation provides ample space for longer names without them overlapping, which can happen with vertical bar charts.
# - Ranking: The natural descending order of the bars (from top to bottom) clearly illustrates the ranking of actors based on their count of distinct appearances, providing an immediate understanding of the most prolific actors in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?:

# %% [markdown]
# From the 'TOP 10 Actors' bar chart, we can observe the following insights:
#
# - George 'Gabby' Hayes is the most prolific actor: With the longest bar, George 'Gabby' Hayes has the highest distinct count of appearances (around 49), indicating he is featured in the most titles in this dataset.
# - Roy Rogers and Bess Flowers are also highly prolific: Roy Rogers and Bess Flowers are close behind, each having a very high distinct count of appearances (around 45 and 44 respectively), suggesting their significant presence in the content library.
# - Consistent High Appearance Counts: All actors in the Top 10 have a substantial number of distinct appearances, ranging from approximately 33 to 49. This indicates a group of highly active and frequently cast individuals within the dataset.
# - Distribution of Appearances: While there's a slight drop-off from the top actor to the tenth, the overall distribution among the top 10 is relatively tight, suggesting that many of these actors were regularly featured.
# - Dominance of a Few Actors: The chart highlights that a relatively small number of actors have a very large number of appearances, which can be characteristic of older content libraries or specific studios that frequently reused talent.

# %% [markdown]
# 3. Will the gained insights help creating a positive business impact?

# %% [markdown]
# Analyzing the 'TOP 10 Actors' can provide valuable insights for Amazon Prime Video, leading to both positive business impacts and potential areas for improvement:
#
# Positive Business Impact:
#
# - Enhanced Content Discoverability and Curation: Knowing the most prolific actors allows for better content curation and promotion. Amazon Prime Video can create special collections or recommendation carousels featuring titles with these popular actors, improving content discoverability for viewers who follow specific talent. This can drive engagement and increase watch time.
# - Targeted Marketing and Audience Retention: If these prolific actors have a dedicated fanbase, Amazon Prime Video can leverage their presence in marketing campaigns. Promoting new content or existing library titles starring these actors can attract new subscribers and retain existing ones who value their work. This is especially true for actors popular in older content categories.
#
# Potential Negative Growth Insights / Missed Opportunities:
#
# - Risk of Stagnation and Lack of New Talent: An over-reliance on a few historically prolific actors might indicate a library heavily skewed towards older content. If Amazon Prime Video doesn't actively acquire or produce content with newer, popular talent, it risks appearing outdated or failing to attract younger demographics, potentially leading to churn among viewers seeking fresh content.
# - Limited Appeal to Diverse Audiences: If the top actors primarily represent a particular era, genre, or demographic, the platform might inadvertently neglect content featuring a wider range of diverse talent. This could limit the platform's appeal to broader, more diverse audiences, potentially missing out on significant subscriber growth segments.

# %% [markdown]
# ## The insights of this dashboard is:

# %% [markdown]
# - Content Overview & Composition
#  - ​Movies vs TV Shows Ratio: The platform’s catalog is heavily skewed toward movies, which account for ~86.3% of total titles (8,511 Movies vs. 1,357 TV Shows).
#  - ​Production Volume Over Time: Title releases remained relatively low and flat throughout most of the 20th century, with significant growth beginning around the 2000s and peaking sharply in recent years.
# - ​Content Categorization & Audience Ratings
#  - ​Maturity / Age Certification: The majority of titles are targeted toward mature audiences, dominated by R (for Movies) and TV-MA / TV-14 (for TV Shows). Family/General content (PG, PG-13, G) makes up a smaller portion of the catalog.
#  - ​Top Genres: Drama is by far the leading genre, followed by Comedy, Documentation, Thriller, and Horror.
# - ​Geographic Distribution & Ratings
#  -​Top Production Countries: The United States heavily dominates content production, followed by India (IN), the United Kingdom (GB), and Canada (CA).
#  - ​IMDb Rating Distribution: Ratings follow a left-skewed distribution peaking around 5.0 to 6.5. Content with extremely high (8.5+) or low (<4.0) ratings represents a minor fraction of total titles.
#
#  - ​IMDb vs. TMDB Score Correlation: There is a strong positive correlation between IMDb and TMDB ratings, indicating consistent user ratings across platforms. Most highly rated content clusters in the 6.0–8.0 range.
# - ​Top Actors: Featured talent is dominated by prolific vintage/classic actors such as Gene Autry, Charles King, Boss Flowers, Roy Rogers, and Herman Hack, showing a strong presence of legacy films/westerns in the collection.

# %% [markdown]
# ## Conclusion
#
# This Exploratory Data Analysis of the Amazon Prime Video dataset has provided a comprehensive overview of its content library, offering valuable insights that can inform strategic decision-making. We began by understanding the dataset's structure, handling duplicates and missing values to ensure data quality.
#
# Through various visualizations and analyses, we uncovered several key aspects:
#
# *   **Content Volume & Trends:** Amazon Prime Video's content library has shown significant growth, especially in recent years, with movies overwhelmingly dominating the content mix.
# *   **Quality & Popularity:** While IMDb and TMDB scores generally correlate well, indicating consistent quality perception, there are nuances in how movies and shows are rated, with shows often exhibiting higher average IMDb scores. Popularity metrics also showed a general positive correlation with quality scores, though some highly-rated niche content might have lower popularity.
# *   **Runtime Characteristics:** Most movies fall within a standard runtime range, while shows are characterized by much shorter, episodic runtimes.
# *   **Genre & Production Diversity:** The platform offers a wide array of genres and originates from numerous production countries, though a few genres and the US dominate the catalog.
#
# ### Business Implications
#
# The insights gleaned directly support Amazon Prime Video's business objectives:
#
# 1.  **Content Strategy Enhancement:** A balanced approach to content acquisition is crucial. While leveraging the strong movie library, increasing investment in high-quality TV shows could attract a broader audience. Diversifying production origins beyond dominant regions and optimizing content for preferred runtimes can also enhance appeal.
# 2.  **Improved User Engagement:** Refining recommendation engines based on score correlations, enhancing content discovery tools, and ensuring clear age certifications across all titles will significantly improve user experience and trust.
# 3.  **Strengthened Competitive Positioning:** Highlighting the platform's strengths, addressing identified content gaps (e.g., in specific genres or regions), and continuously monitoring content trends are vital for maintaining a competitive edge in the dynamic streaming market.
#
# In essence, a data-driven strategy focusing on content diversification, quality assurance, and enhanced user experience, informed by continuous analytical feedback, will enable Amazon Prime Video to grow its subscriber base and solidify its position in the competitive streaming landscape.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
